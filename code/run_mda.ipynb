# %%
import sys
sys.path.append('/home/thies/repos/BIU/')
import biu
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
plt.rcParams['svg.fonttype'] = 'none'

import seaborn as sns
import scipy

from rdmpy import RDM
RDM.meta(source="repos/UA_isala/metabolomics/code/initial_investigation.ipynb")

R = biu.R()

# %% [markdown]
# # Load data

# %%
R("""
load('../data/raw/Isala_tt_merged_genus_fixed.RData')
""")
samples = R("Isala.tt.merged_genus$samples")
taxa    = R("Isala.tt.merged_genus$taxa")
abundances = R("Isala.tt.merged_genus$counts")


samples = samples[(samples.high_quality == 1) & (samples.include == 1) & (samples.flow == 'F1')]

abundances = abundances[abundances.sample_id.isin(samples.sample_id)]
abundances = abundances.pivot(index='sample_id', columns='taxon_id', values='count').fillna(0)
abundances = abundances.rename(columns=dict(zip(taxa.taxon_id, taxa.taxon.apply(lambda x: x.replace(' ', '_')))))

samples = samples.set_index('sample_id')

# %%
biu.ops.lst.freq(samples['General.Highest.Education'])

for l in set(samples['General.Highest.Education']):
    if l not in ['PhD', 'Secondary education', 'College', 'University']:
        continue
    #fi
    samples['General.Highest.Education.%s' % l.replace(' ','')] = samples['General.Highest.Education'].apply(lambda x: None if pd.isna(x) else x == l)
    print('General.Highest.Education.%s' % l.replace(' ',''))
#efor
# Out:
# General.Highest.Education.Secondaryeducation
# General.Highest.Education.PhD
# General.Highest.Education.College
# General.Highest.Education.University

# %%
samples['Menopause'] = samples['Menopause'].apply(lambda x: {1:True, 0:False}.get(x,None))
samples['Reproductive.Contraception.Hormonal.3months'] = samples['Reproductive.Contraception.Hormonal.3months'].apply(lambda x: {1:True, 0:False}.get(x,None))
samples['Health.Medication.Menopause.HRT'] = samples['Health.Medication.Menopause.HRT'].apply(lambda x: {1:True, 0:False}.get(x,None))
samples['Lifestyle.Drugs.Current_smoker'] = samples['Lifestyle.Drugs.Current_smoker'].apply(lambda x: {1:True, 0:False}.get(x,None))

# %% [markdown]
# ## Prepare mda input

# %%
def write_mda_input(features, metadata, formulas, path):
    biu.utils.fs.mkdirp(path)
    with open('%s/input_formulas.txt' % path, 'w') as ofd:
        for f in formulas:
            ofd.write(f + '\n')
        #efor
    #ewith
    
    features.reset_index().to_csv('%s/input_counts.tsv' % path , sep='\t', index=False)
    metadata.reset_index().to_csv('%s/input_meta.tsv' % path , sep='\t', index=False)
    print("wrote")
#edef

# %%
variables = [
    "Menopause",
    "Reproductive.Contraception.Hormonal.3months",
    "Health.Medication.Menopause.HRT",
    "Reproductive.Pregnancy.n",
    "General.Highest.Education.Secondaryeducation",
    "General.Highest.Education.PhD",
    "General.Highest.Education.College",
    "General.Highest.Education.University",
    "General.Age",
    "Lifestyle.Drugs.Current_smoker"
]

formulas = ['~' + '+'.join(variables)]

outdir = '/home/thies/repos/UA_isala/menopause/processing/mda/'
write_mda_input(abundances, samples[variables], formulas, outdir)
# Out:
# wrote

# %%
samples[variables].dropna().shape
# Out:
# (1330, 10)

# %% [markdown]
# # Run MDA

# %%
mda_cmd_code = """
taskset -c {cpus} ~/repos/devel/multidiffabundance/MDA/mda \\
    --docker \\
    --{method} \\
    "{counts}" \\
    "{metadata}" \\
    "{formulas}" \\
    "{output}"
"""

def print_runcode(outdir, method, suffix=None):
    
    print(mda_cmd_code.format(cpus="%d-%d" % (0,5),
                              method=method,
                              counts="%s/input_counts.tsv" % outdir,
                              metadata="%s/input_meta.tsv" % outdir,
                              formulas="%s/input_formulas.txt" % outdir,
                              output="%s/output_%s" % (outdir, method if suffix is None else suffix)))
    
#edef

# %% [markdown]
# ## Beta

# %%
print_runcode(outdir, 'beta')
# Out:
# taskset -c 0-5 ~/repos/devel/multidiffabundance/MDA/mda \
#     --docker \
#     --beta \
#     "/home/thies/repos/UA_isala/menopause/processing/mda//input_counts.tsv" \
#     "/home/thies/repos/UA_isala/menopause/processing/mda//input_meta.tsv" \
#     "/home/thies/repos/UA_isala/menopause/processing/mda//input_formulas.txt" \
#     "/home/thies/repos/UA_isala/menopause/processing/mda//output_beta"

# %%
Rbeta = pd.read_csv('/mnt/a-samsung-mz7lm480-ssd/thies/UA_isala/menopause/processing/mda/output_beta/results.full.tsv', sep='\t')

# %%
Rbeta
# Out:
#        taxa                                          variable  effectsize  se  \
# 0  mda.beta                                     MenopauseTRUE    0.000741 NaN
# 1  mda.beta       Reproductive.Contraception.Hormonal.3months    0.000421 NaN
# 2  mda.beta                   Health.Medication.Menopause.HRT    0.000539 NaN
# 3  mda.beta                          Reproductive.Pregnancy.n    0.007712 NaN
# 4  mda.beta  General.Highest.Education.SecondaryeducationTRUE    0.000111 NaN
# 5  mda.beta                 General.Highest.Education.PhDTRUE    0.000174 NaN
# 6  mda.beta             General.Highest.Education.CollegeTRUE    0.000139 NaN
# 7  mda.beta          General.Highest.Education.UniversityTRUE    0.000202 NaN
# 8  mda.beta                                       General.Age    0.002332 NaN
# 9  mda.beta                    Lifestyle.Drugs.Current_smoker    0.000431 NaN
#
#         stat  pvalue  qvalue.withinformula  qvalue  \
# 0   2.418922   0.042                 0.042   0.042
# 1   1.376025     NaN                   NaN     NaN
# 2   1.759020     NaN                   NaN     NaN
# 3  25.189791     NaN                   NaN     NaN
# 4   0.362664     NaN                   NaN     NaN
# 5   0.568367     NaN                   NaN     NaN
# 6   0.454570     NaN                   NaN     NaN
# 7   0.659887     NaN                   NaN     NaN
# 8   7.616105     NaN                   NaN     NaN
# 9   1.407334     NaN                   NaN     NaN
#
#                                              formula method     n  \
# 0  ~MenopauseTRUE + Reproductive.Contraception.Ho...   beta  3192
# 1  ~MenopauseTRUE + Reproductive.Contraception.Ho...   beta  3192
# 2  ~MenopauseTRUE + Reproductive.Contraception.Ho...   beta  3192
# 3  ~MenopauseTRUE + Reproductive.Contraception.Ho...   beta  3192
# 4  ~MenopauseTRUE + Reproductive.Contraception.Ho...   beta  3192
# 5  ~MenopauseTRUE + Reproductive.Contraception.Ho...   beta  3192
# 6  ~MenopauseTRUE + Reproductive.Contraception.Ho...   beta  3192
# 7  ~MenopauseTRUE + Reproductive.Contraception.Ho...   beta  3192
# 8  ~MenopauseTRUE + Reproductive.Contraception.Ho...   beta  3192
# 9  ~MenopauseTRUE + Reproductive.Contraception.Ho...   beta  3192
#
#              freq  comment
# 0   0:3083, 1:109      NaN
# 1             NaN      NaN
# 2             NaN      NaN
# 3             NaN      NaN
# 4   0:2572, 1:620      NaN
# 5   0:3083, 1:109      NaN
# 6  0:2145, 1:1047      NaN
# 7  0:1801, 1:1391      NaN
# 8             NaN      NaN
# 9             NaN      NaN

# %% [markdown]
# ## Alpha

# %%
print_runcode(outdir, 'alpha')
# Out:
# taskset -c 0-5 ~/repos/devel/multidiffabundance/MDA/mda \
#     --docker \
#     --alpha \
#     "/home/thies/repos/UA_isala/menopause/processing/mda//input_counts.tsv" \
#     "/home/thies/repos/UA_isala/menopause/processing/mda//input_meta.tsv" \
#     "/home/thies/repos/UA_isala/menopause/processing/mda//input_formulas.txt" \
#     "/home/thies/repos/UA_isala/menopause/processing/mda//output_alpha"

# %%
Ralpha = pd.read_csv('/mnt/a-samsung-mz7lm480-ssd/thies/repos/UA_isala/menopause/processing/mda/output_alpha/results.tsv', sep='\t')
Ralpha
# Out:
#                 taxa       variable  effectsize        se      stat    pvalue  \
# 0  mda.alpha.shannon  MenopauseTRUE    0.152202  0.127169  1.196846  0.231582
#
#    qvalue.withinformula    qvalue  \
# 0              0.231582  0.231582
#
#                                              formula method     n  \
# 0  ~MenopauseTRUE + Reproductive.Contraception.Ho...  alpha  1330
#
#             freq  comment
# 0  0:1221, 1:109      NaN

# %%
biu.ops.lst.freq(samples['Menopause'])
# Out:
# {1: 3089, 2: 110, -2147483648: 5}

# %% [markdown]
# ## MDA

# %%
print_runcode(outdir, 'lmclr --limma --deseq2 --maaslin2 --aldex2', suffix="mda")
# Out:
# taskset -c 0-5 ~/repos/devel/multidiffabundance/MDA/mda \
#     --docker \
#     --lmclr --limma --deseq2 --maaslin2 --aldex2 \
#     "/home/thies/repos/UA_isala/menopause/processing/mda//input_counts.tsv" \
#     "/home/thies/repos/UA_isala/menopause/processing/mda//input_meta.tsv" \
#     "/home/thies/repos/UA_isala/menopause/processing/mda//input_formulas.txt" \
#     "/home/thies/repos/UA_isala/menopause/processing/mda//output_mda"

# %%
Rmda = pd.read_csv('/mnt/a-samsung-mz7lm480-ssd/thies/repos/UA_isala/menopause/processing/mda/output_mda/results.tsv', sep='\t')

# %%
Rmda[Rmda.qvalue < 0.05]
# Out:
#                               taxa       variable  effectsize        se  \
# 90                  Staphylococcus  MenopauseTRUE   -1.385257  0.405612
# 103                     Aerococcus  MenopauseTRUE    1.631280  0.015030
# 105                   Anaerococcus  MenopauseTRUE    2.825566  0.024661
# 107                      Atopobium  MenopauseTRUE    1.168295  0.013058
# 108                Bifidobacterium  MenopauseTRUE    3.181079  0.021402
# 110                Corynebacterium  MenopauseTRUE    1.406032  0.020090
# 111                      Dialister  MenopauseTRUE    2.367748  0.022407
# 113                      Facklamia  MenopauseTRUE    0.953042  0.014509
# 116                     Finegoldia  MenopauseTRUE    2.424085  0.024125
# 119  Lactobacillus_crispatus_group  MenopauseTRUE    2.922496  0.024574
# 133                Peptoniphilus_A  MenopauseTRUE    1.570525  0.023629
# 139                     Prevotella  MenopauseTRUE    3.603635  0.028507
# 149                    Varibaculum  MenopauseTRUE    1.129359  0.015627
# 181                      Atopobium  MenopauseTRUE    0.587437  0.146299
# 204                      Atopobium  MenopauseTRUE    1.319179  0.005888
# 205                     Aerococcus  MenopauseTRUE    1.279637  0.010856
#
#          stat        pvalue  qvalue.withinformula        qvalue  \
# 90  -3.415226  6.372900e-04          3.058992e-02  3.058992e-02
# 103  3.566961  3.735643e-04          2.441170e-03  2.441170e-03
# 105  4.494475  7.560936e-06          1.890234e-04  1.890234e-04
# 107  3.729260  1.998645e-04          1.665537e-03  1.665537e-03
# 108  4.245350  2.329214e-05          2.911518e-04  2.911518e-04
# 110  2.520636  1.182687e-02          4.927864e-02  4.927864e-02
# 111  4.246592  2.316518e-05          2.911518e-04  2.911518e-04
# 113  2.626901  8.712595e-03          3.960270e-02  3.960270e-02
# 116  4.142367  3.647312e-05          3.647312e-04  3.647312e-04
# 119  3.555153  3.905872e-04          2.441170e-03  2.441170e-03
# 133  2.768838  5.701361e-03          2.850681e-02  2.850681e-02
# 139  5.192492  2.387479e-07          1.193740e-05  1.193740e-05
# 149  2.829105  4.735751e-03          2.630973e-02  2.630973e-02
# 181  4.015325  6.270928e-05          3.135464e-03  3.135464e-03
# 204       NaN  1.069566e-09          5.347830e-08  5.347830e-08
# 205       NaN  1.258718e-03          3.146796e-02  3.146796e-02
#
#                                                formula    method     n  \
# 90   ~MenopauseTRUE + Reproductive.Contraception.Ho...    deseq2  1330
# 103  ~MenopauseTRUE + Reproductive.Contraception.Ho...     limma  1330
# 105  ~MenopauseTRUE + Reproductive.Contraception.Ho...     limma  1330
# 107  ~MenopauseTRUE + Reproductive.Contraception.Ho...     limma  1330
# 108  ~MenopauseTRUE + Reproductive.Contraception.Ho...     limma  1330
# 110  ~MenopauseTRUE + Reproductive.Contraception.Ho...     limma  1330
# 111  ~MenopauseTRUE + Reproductive.Contraception.Ho...     limma  1330
# 113  ~MenopauseTRUE + Reproductive.Contraception.Ho...     limma  1330
# 116  ~MenopauseTRUE + Reproductive.Contraception.Ho...     limma  1330
# 119  ~MenopauseTRUE + Reproductive.Contraception.Ho...     limma  1330
# 133  ~MenopauseTRUE + Reproductive.Contraception.Ho...     limma  1330
# 139  ~MenopauseTRUE + Reproductive.Contraception.Ho...     limma  1330
# 149  ~MenopauseTRUE + Reproductive.Contraception.Ho...     limma  1330
# 181  ~MenopauseTRUE + Reproductive.Contraception.Ho...     lmclr  1330
# 204  ~MenopauseTRUE + Reproductive.Contraception.Ho...  maaslin2  1330
# 205  ~MenopauseTRUE + Reproductive.Contraception.Ho...  maaslin2  1330
#
#               freq  comment
# 90   0:1221, 1:109      NaN
# 103  0:1221, 1:109      NaN
# 105  0:1221, 1:109      NaN
# 107  0:1221, 1:109      NaN
# 108  0:1221, 1:109      NaN
# 110  0:1221, 1:109      NaN
# 111  0:1221, 1:109      NaN
# 113  0:1221, 1:109      NaN
# 116  0:1221, 1:109      NaN
# 119  0:1221, 1:109      NaN
# 133  0:1221, 1:109      NaN
# 139  0:1221, 1:109      NaN
# 149  0:1221, 1:109      NaN
# 181  0:1221, 1:109      NaN
# 204  0:1221, 1:109      NaN
# 205  0:1221, 1:109      NaN
